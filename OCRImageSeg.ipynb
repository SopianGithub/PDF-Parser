# %%
from PIL import Image
import pytesseract

image = 'samples/ivca_goto.png'
text = pytesseract.image_to_string(Image.open(image), lang="eng")
print(text)
# Out:
# Supporting Industry
#
# + Food & beverages
# Industry
#
# + ITindustry
#
# + E-commerce
#
# + Supermarket
#
# + Pharmacy
#
# E-commerce
# (Tokopedia)
# * Ecommerce
# + Food & Beverage
# + Payment Service
# ORCAS tokopedia
# * Travel &
#
# Entertainment
#
# ‘Sudah di delivery
#
# Supporting Industry
#
# ‘On-Demand (Gojek)
# + Supplier (helm
#
# Jaket)
#
# + Food & beverages
# Industry
#
# + |Tindustry
#
# * E-commerce
#
# = Supermarket
#
# + Pharmacy
#
# E-commerce
# (Tokopedia)
#
# * Ecommerce
#
# + Food & Beverage
# + Payment Service
#
# + Merchant/ Official
#
# tokopedia
#
# Financial Tech (Goto
#
# Financial)
#
# * Otorisasito
# ecommerce
#
# iy
#
# Industrial Value Chain Analysis GoTo Group
#
# Pasar Modal Perbankan Sekuritas & Bursa Efek
# PFumintastcture | WRManagement_— | TechDevelopment | Procurement |
# Stretegic Planning, Legal & .
# 2 IT System & Operation,
# Reg.Compl, Financial Policy, Human Resource Development " Procurement, Warehouse
# Conarrurity Affair Aplication Development.
#
# ON-DEMAND (GOJEK)
#
# * Driver = Requesting the rides * Mobile Aplication + Social Media Mobility & Food & Lifestyle &
# * Attribute (Helm, + Ride + Payment for marketing Logistics Groceries Entertainment
# Jaket, dil) * Pay andGo ‘Customer *SalesPromotion —* Goride * Gofood * Gogames
# + Quality control * Web and Apps + Paymnent For (Voucher) + Gocar ‘+ Gomart + Goplay
# materials Maintenance Driver + Events * Gosend + Goshop + Gotix
# * Mainly hardware * Driver Traini * Payment with go —* Gobluebird * Gonews:
# (server) pay * Gotransit * Goservice
# * Employees * Go Point * Gobox * Gofitness
# + Sales marketing * Gomed
# * Gomall
# Operator Seluler Merchant
#
# E-COMMERCE (TOKOPEDIA)
#
# Individual
#
# + Warehouse + Maintenance + Mobile Aplication + SocialMedia + Marketplace * Dhanapala
# Application + Payment for marketing + Tokopedia Salam + Tokopedia Parent nt
# Merchant + Sales Promotion + Produk digital + Go Food Mercha
# (Voucher) + Tokopedia Now + Travel & Entrtainment
# + Events + Tokopedia Nyam + Top-Up & Tagihan Corporate
# + Payment with go + Tokopedia Wedding —_* Keuangan
# pay + Tokopedia Print + Bangga Lokal
# Related Industry
# Supplier Merchant
#
# FINANCIAL TECH (GOTO FINANCIAL)
#
# * Otorisasi di * Server * Social Media Financial Services * Midtrans
# ecommerce * Web Application marketing * Gopay * Selly
# * Sales Marketing _* Paylater + Moka
# * Gostore
# * Gosure Partnership with +20
# * Goinvestasi banks and financial
# + Gobiz institution
# Related Industry >
# Bank Bank Indonesia OlK Merchant
# Layanan 1500
#
# Pasar Modal Perbankan Sekuritas & BursaEfek
# | __Firminfrastructure__ | HR Management| TechDevelopment | Procurement
#
# Strategic Planning, Legal & ™ a ae
# Reg.Compl, Financial Policy, Human Resource Development i
# Communi i Aplication Development ; a
#
# ON-DEMAND (GOJEK)
#
# * Driver + Requesting the rides * Mobile Aplication + Social Media Mobility & Food & Lifestyle &
# * Attribute (Helm, * Ride + Payment for marketing Logistics Groceries Entertainment
# Jaket, dil) + Pay and Go Customer * Sales Promotion + Goride * Gofood * Gogames
# * Quality control * Web and Apps * Paymnent For (Voucher) * Gocar * Gomart *Goplay
# materials Maintenance Driver + Events ——*Gosend____+Goshop __ + Gotix
# + Mainlyhardware ——* Driver Training * Payment with go * Gobluebird *Gonews
# (server) pay + Gotransit * Goservice
# + Employees * Go Point * Gobox *Gofitness
# - + Sales marketing *Gomed ~
# _ * Gomalt
# Operator Seluler Merchant a #@p
#
# E-COMMERCE (TOKOPEDIA)
#
# imbue [Onward | rn a |
#
# Services
# Individual
#
# + Warehouse + Maintenance * Mobile Aplication + Social Media + Marketplace + Dhanapala
# Application + Payment for marketing Tokopedia Salam —_/* Tokopedia Parent nt
# ‘Merchant + Sales Promotion“ Produkdigtal ~~ + Go Food Merchay
# (Voucher) _* Tokopedia Now + Travel & Entrtainment
# + Events + Tokopedia Nyam + Top-Up & Tagihan Corporate
# + Paymentwith go + Tokopedia Wedding + Keuangan
# pay + Tokopedia Print + Bangga Lokal
# Related Industry
# ‘Supplier Merchant
#
# FINANCIAL TECH (GOTO FINANCIAL)
#
# + Otorisasi di * Social Media Financial Services + Midtrans
# ecommerce . swab Application _ marketing * Gopay * Selly
# * Sales Marketing * Paylater + Moka
# * Gostore
# * Gosure Partnership with +20
# * Goinvestasi banks and financial
# * Gobiz institution
# Related Industry
# Bank Bank Indonesia uk Merchant

# %%
import cv2
from pytesseract import pytesseract

img = cv2.imread('samples/ivca_goto.png')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, thresh1 = cv2.threshold(gray, 0, 255, cv2.THRESH_OTSU |
                                          cv2.THRESH_BINARY_INV)
cv2.imwrite('threshold_image.jpg',thresh1)
# Out:
# True

# %%
rect_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (12, 12))

dilation = cv2.dilate(thresh1, rect_kernel, iterations = 3)
cv2.imwrite('dilation_image.jpg',dilation)
# Out:
# True

# %%
contours, hierarchy = cv2.findContours(dilation, cv2.RETR_EXTERNAL,
                                            cv2.CHAIN_APPROX_NONE)

im2 = img.copy()

im2
# for cnt in contours:
#     x, y, w, h = cv2.boundingRect(cnt)
     
#     # Draw the bounding box on the text area
#     rect=cv2.rectangle(im2, (x, y), (x + w, y + h), (0, 255, 0), 2)
     
#     # Crop the bounding box area
#     cropped = im2[y:y + h, x:x + w]
    
#     cv2.imwrite('rectanglebox.jpg',rect)
     
#     # open the text file
#     file = open("text_output2.txt", "a")
     
#     # Using tesseract on the cropped image area to get text
#     text = pytesseract.image_to_string(cropped)
     
#     # Adding the text to the file
#     file.write(text)
#     file.write("\n")
     
#     # Closing the file
#     file.close
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 contours, hierarchy = cv2.findContours(dilation, cv2.RETR_EXTERNAL,
#       2                                             cv2.CHAIN_APPROX_NONE)
#       4 im2 = img.copy()
#       6 im2
#
# NameError: name 'cv2' is not defined
